# %% [markdown]
# <a href="https://colab.research.google.com/github/salmaafiata/Pyhton/blob/main/Tugas_10_Pyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
#import libaries
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
#load image
imagepaths = paths.list_images("3scene")
data = []
labels = []

# %%
#resize image
for imagepath in imagepaths:
  image = Image.open(imagepath)
  image = np.array(image.resize((64, 64))) / 255.0
  data.append(image)
  #extract label
  label = imagepath.split(os.path.sep)[-2]
  labels.append(label)

# %%
#convert label from string to binary
lb = LabelBinarizer()
labels =  lb.fit_transform(labels)

# %%
#Split Train and Test data
(x_train, x_test, y_train, y_test) = train_test_split(np.array(data), np.array(labels), test_size = 0.25, shuffle = True)
print(x_train.shape)
print(x_test.shape)
# Out:
# (711, 64, 64, 3)
# (237, 64, 64, 3)

# %%
#Build Model
model = Sequential();
#Flatten Layer
model.add(Flatten(input_shape=(64*64*3,)));
#Hidden Layer#1
model.add(Dense(units=100,
                  activation='relu',
                  kernel_initializer='uniform',));

#Hidden Layer#2
model.add(Dense(units=16,
                  activation='relu',
                  kernel_initializer='uniform'));
#Hidden Layer#2                
model.add(Dense(units=16,
                  activation='relu',
                  kernel_initializer='uniform'));

#Exit Layer
model.add(Dense(units=3,
                  activation='softmax',
                  kernel_initializer='uniform'));

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               1228900
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                1616
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 1,230,839
# Trainable params: 1,230,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train Model
opt = Adam(lr=3e-4)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 16/23 [===================>..........] - ETA: 0s - loss: 1.0972 - accuracy: 0.4062WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0966 - accuracy: 0.3924 - val_loss: 1.0927 - val_accuracy: 0.3882
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1.0837 - accuracy: 0.4318 - val_loss: 1.0750 - val_accuracy: 0.3586
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1.0442 - accuracy: 0.4529 - val_loss: 1.0173 - val_accuracy: 0.5021
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.9898 - accuracy: 0.5274 - val_loss: 0.9573 - val_accuracy: 0.5401
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.9262 - accuracy: 0.5415 - val_loss: 0.9074 - val_accuracy: 0.5570
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8838 - accuracy: 0.5738 - val_loss: 0.8695 - val_accuracy: 0.5654
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8643 - accuracy: 0.5738 - val_loss: 0.8505 - val_accuracy: 0.6287
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8504 - accuracy: 0.5584 - val_loss: 0.8263 - val_accuracy: 0.6076
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8222 - accuracy: 0.5851 - val_loss: 0.8114 - val_accuracy: 0.6118
# Epoch 10/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8030 - accuracy: 0.5921 - val_loss: 0.8290 - val_accuracy: 0.5696
# Epoch 11/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7986 - accuracy: 0.6203 - val_loss: 0.8055 - val_accuracy: 0.5992
# Epoch 12/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7864 - accuracy: 0.6006 - val_loss: 0.7770 - val_accuracy: 0.6118
# Epoch 13/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7724 - accuracy: 0.6104 - val_loss: 0.7615 - val_accuracy: 0.6203
# Epoch 14/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7656 - accuracy: 0.6160 - val_loss: 0.7506 - val_accuracy: 0.6203
# Epoch 15/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7377 - accuracy: 0.6273 - val_loss: 0.7408 - val_accuracy: 0.6371
# Epoch 16/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7153 - accuracy: 0.6273 - val_loss: 0.7367 - val_accuracy: 0.6540
# Epoch 17/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6999 - accuracy: 0.6610 - val_loss: 0.7280 - val_accuracy: 0.6371
# Epoch 18/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6871 - accuracy: 0.6582 - val_loss: 0.7235 - val_accuracy: 0.6751
# Epoch 19/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7259 - accuracy: 0.6259 - val_loss: 0.7487 - val_accuracy: 0.7046
# Epoch 20/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7213 - accuracy: 0.6554 - val_loss: 0.7663 - val_accuracy: 0.6160
# Epoch 21/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6733 - accuracy: 0.6976 - val_loss: 0.7152 - val_accuracy: 0.6624
# Epoch 22/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6485 - accuracy: 0.6779 - val_loss: 0.6898 - val_accuracy: 0.7384
# Epoch 23/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6418 - accuracy: 0.7384 - val_loss: 0.6921 - val_accuracy: 0.6920
# Epoch 24/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6265 - accuracy: 0.7412 - val_loss: 0.6818 - val_accuracy: 0.7342
# Epoch 25/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6051 - accuracy: 0.7623 - val_loss: 0.6767 - val_accuracy: 0.7511
# Epoch 26/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6283 - accuracy: 0.7440 - val_loss: 0.6987 - val_accuracy: 0.6709
# Epoch 27/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6007 - accuracy: 0.7567 - val_loss: 0.6520 - val_accuracy: 0.7764
# Epoch 28/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5770 - accuracy: 0.7834 - val_loss: 0.6696 - val_accuracy: 0.7637
# Epoch 29/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5733 - accuracy: 0.7792 - val_loss: 0.6576 - val_accuracy: 0.7806
# Epoch 30/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5478 - accuracy: 0.7890 - val_loss: 0.6297 - val_accuracy: 0.7806
# Epoch 31/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5383 - accuracy: 0.8143 - val_loss: 0.6349 - val_accuracy: 0.7890
# Epoch 32/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5644 - accuracy: 0.7890 - val_loss: 0.6252 - val_accuracy: 0.7806
# Epoch 33/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5469 - accuracy: 0.7904 - val_loss: 0.6189 - val_accuracy: 0.7806
# Epoch 34/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5092 - accuracy: 0.8312 - val_loss: 0.6144 - val_accuracy: 0.7932
# Epoch 35/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5177 - accuracy: 0.7989 - val_loss: 0.6107 - val_accuracy: 0.7848
# Epoch 36/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4976 - accuracy: 0.8256 - val_loss: 0.6238 - val_accuracy: 0.7806
# Epoch 37/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4781 - accuracy: 0.8270 - val_loss: 0.5972 - val_accuracy: 0.7890
# Epoch 38/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4664 - accuracy: 0.8354 - val_loss: 0.5866 - val_accuracy: 0.7890
# Epoch 39/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4530 - accuracy: 0.8481 - val_loss: 0.5971 - val_accuracy: 0.7932
# Epoch 40/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4421 - accuracy: 0.8439 - val_loss: 0.5909 - val_accuracy: 0.8017
# Epoch 41/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4360 - accuracy: 0.8537 - val_loss: 0.5736 - val_accuracy: 0.8059
# Epoch 42/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4339 - accuracy: 0.8551 - val_loss: 0.5602 - val_accuracy: 0.8017
# Epoch 43/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4324 - accuracy: 0.8467 - val_loss: 0.5616 - val_accuracy: 0.8059
# Epoch 44/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4224 - accuracy: 0.8622 - val_loss: 0.5605 - val_accuracy: 0.8228
# Epoch 45/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.8425 - val_loss: 0.5692 - val_accuracy: 0.8101
# Epoch 46/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3994 - accuracy: 0.8608 - val_loss: 0.5877 - val_accuracy: 0.8186
# Epoch 47/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3875 - accuracy: 0.8622 - val_loss: 0.5825 - val_accuracy: 0.7932
# Epoch 48/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4200 - accuracy: 0.8242 - val_loss: 0.5499 - val_accuracy: 0.8354
# Epoch 49/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3727 - accuracy: 0.8748 - val_loss: 0.5455 - val_accuracy: 0.8312
# Epoch 50/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3644 - accuracy: 0.8790 - val_loss: 0.5512 - val_accuracy: 0.8439

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
predictions = model.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.82      0.89      0.85        80
#       forest       0.91      0.83      0.87        93
#      highway       0.80      0.81      0.81        64
#
#     accuracy                           0.84       237
#    macro avg       0.84      0.84      0.84       237
# weighted avg       0.85      0.84      0.84       237

# %%
model.save('imageclassificationmodel')
# Out:
# INFO:tensorflow:Assets written to: imageclassificationmodel/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='test.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()

# %%
image_testing = Image.open('test.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (1, 64, 64, 3).
# [[0.5633691  0.00077579 0.43585515]]
# ['coast']
